# %% [markdown]
# Module 2:- Data Cleaning and Feature Engineering

# %% [markdown]
# ** 1. Check Missing Values Again**

# %%
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of        Ticket_ID  Created_Date  Resolution_Date  Status  Priority  \
# 0          False         False            False   False     False
# 1          False         False            False   False     False
# 2          False         False            False   False     False
# 3          False         False            False   False     False
# 4          False         False            False   False     False
# ...          ...           ...              ...     ...       ...
# 11995      False         False            False   False     False
# 11996      False         False            False   False     False
# 11997      False         False            False   False     False
# 11998      False         False            False   False     False
# 11999      False         False            False   False     False
#
#        Ticket_Type  Category  Country  Region  Latitude  ...  Customer_ID  \
# ...

# %%
df["Customer_Satisfaction"] = df["Customer_Satisfaction"].fillna(0)

# %%
df["Resolution_Code"] = df["Resolution_Code"].fillna("Pending")

# %%
df["Resolution_Notes"] = df["Resolution_Notes"].fillna("No Resolution Yet")

# %%
# Fill missing Customer Satisfaction values with 0
df["Customer_Satisfaction"] = df["Customer_Satisfaction"].fillna(0)

# %%
print("Missing values in Customer_Satisfaction:")
print(df["Customer_Satisfaction"].isnull().sum())
# Out:
# Missing values in Customer_Satisfaction:
# 0

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
df = df.drop_duplicates()

# %%
date_columns = [
    "Created_Date",
    "Resolution_Date",
    "First_Response_Date"
]

for col in date_columns:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
#remove empty spaces
text_columns = df.select_dtypes(include="object").columns

for col in text_columns:
    df[col] = df[col].str.strip()

# %%
df["Resolution_Duration"] = (
    df["Resolution_Date"] -
    df["Created_Date"]
).dt.days

# %%
priority_map = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

df["Priority_Score"] = df["Priority"].map(priority_map)

# %%
df["First_Response_Time"] = (
    df["First_Response_Date"] -
    df["Created_Date"]
).dt.total_seconds() / 3600

# %%
print(df[[
    "Resolution_Duration",
    "Priority_Score",
    "First_Response_Time"
]].head())
# Out:
#    Resolution_Duration  Priority_Score  First_Response_Time
# 0                  5.0               2            19.520278
# 1                  3.0               1            13.318611
# 2                  3.0               2             9.108333
# 3                  2.0               2             5.322500
# 4                  2.0               3             1.335556

# %%
import numpy as np

queue_list = [
    "Service Desk",
    "Network Support",
    "Application Support",
    "Database Support",
    "Infrastructure Support",
    "Security Operations",
    "Hardware Support",
    "Access Management"
]

# Create Queue column
df["Queue"] = np.random.choice(queue_list, size=len(df))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ticket_ID              12000 non-null  object
#  1   Created_Date           12000 non-null  datetime64[ns]
#  2   Resolution_Date        11059 non-null  datetime64[ns]
#  3   Status                 12000 non-null  object
#  4   Priority               12000 non-null  object
#  5   Ticket_Type            12000 non-null  object
#  6   Category               12000 non-null  object
#  7   Country                12000 non-null  object
#  8   Region                 12000 non-null  object
#  9   Latitude               12000 non-null  float64
#  10  Longitude              12000 non-null  float64
#  11  Cluster_ID             12000 non-null  int64
#  12  Cluster_Name           12000 non-null  object
#  13  Similarity_Score       12000 non-null  float64
# ...

# %%
df.to_csv("IT_Support_Ticket_Dataset_Cleaned.csv", index=False)

# %%
df=pd.read_csv('/content/IT_Support_Ticket_Dataset_Cleaned.csv')
print(df.head())
# Out:
#    Ticket_ID         Created_Date      Resolution_Date    Status Priority  \
# 0  TCK-00001  2025-05-30 20:01:00  2025-06-05 08:01:05  Resolved   Medium
# 1  TCK-00002  2025-09-01 02:36:00  2025-09-04 13:18:55    Closed      Low
# 2  TCK-00003  2025-09-17 21:28:00  2025-09-20 23:18:21    Closed   Medium
# 3  TCK-00004  2025-02-10 14:44:00  2025-02-13 05:15:04    Closed   Medium
# 4  TCK-00005  2025-02-04 00:34:00  2025-02-06 14:22:02    Closed     High
#
#   Ticket_Type     Category Country Region  Latitude  ...        Product  \
# 0      Change      Network   India   APAC   21.0833  ...     VPN Client
# 1      Change          Bug  Brazil   AMER  -16.2870  ...     VPN Client
# 2     Problem  Integration  Canada   AMER   55.5853  ...  Cloud Storage
# 3    Incident  Performance   Japan   APAC   35.4838  ...      ERP Suite
# 4    Incident     Software     USA   AMER   36.4441  ...      ERP Suite
#
#    Customer_Satisfaction Escalation_Level  Device_Type Operating_System  \
# ...
