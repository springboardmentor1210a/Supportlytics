# %%
import pandas as pd

df = pd.read_excel("Supportlytics_20000.xlsx")

df.head()
# Out:
#    Ticket_ID      Created_Date   Resolution_Date    Status  Priority  \
# 0  TKT000001  2025-04-14 22:00  2025-04-17 22:00      Open    Medium
# 1  TKT000002  2026-03-30 02:00  2026-03-30 02:00  Resolved       Low
# 2  TKT000003  2025-06-13 21:00  2025-06-15 21:00    Closed  Critical
# 3  TKT000004  2025-03-22 01:00  2025-03-24 01:00  Resolved      High
# 4  TKT000005  2025-01-14 11:00  2025-01-18 11:00  Resolved      High
#
#   Ticket_Type           Category Country  Cluster_ID  \
# 0     Request            Network     USA           1
# 1     Problem           Software     UAE           2
# 2     Request           Software     USA           2
# 3    Incident              Email   India           7
# 4     Request  Access Management  Canada           8
#
#                Cluster_Name  ...  Channel  \
# 0            Network Issues  ...   Portal
# 1           Software Issues  ...    Phone
# 2           Software Issues  ...    Phone
# 3              Email Issues  ...     Chat
# 4  Access Management Issues  ...     Chat
#
#                                Description                       Tags  \
# 0               VPN related network issue.            network,support
# 1              ERP related software issue.           software,support
# 2              ERP related software issue.           software,support
# 3             Outlook related email issue.              email,support
# 4  Unlock related access management issue.  access management,support
#
#       Product Customer_Satisfaction Escalation_Level         Region  \
# 0         VPN                     3               L2  North America
# 1  ServiceNow                     2               L3  North America
# 2  ServiceNow                     5               L3         Europe
# 3         SAP                     2               L3         Europe
# 4         SAP                     4               L1  North America
#
#   Device_Type Operating_System  \
# 0      Mobile             RHEL
# 1      Mobile           Ubuntu
# 2      Mobile           Ubuntu
# 3      Laptop       Windows 11
# 4      Server             RHEL
#
#                                     Resolution_Notes
# 0            Resolved after troubleshooting network.
# 1           Resolved after troubleshooting software.
# 2           Resolved after troubleshooting software.
# 3              Resolved after troubleshooting email.
# 4  Resolved after troubleshooting access management.
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Ticket_ID              20000 non-null  str
#  1   Created_Date           20000 non-null  str
#  2   Resolution_Date        20000 non-null  str
#  3   Status                 20000 non-null  str
#  4   Priority               20000 non-null  str
#  5   Ticket_Type            20000 non-null  str
#  6   Category               20000 non-null  str
#  7   Country                20000 non-null  str
#  8   Cluster_ID             20000 non-null  int64
#  9   Cluster_Name           20000 non-null  str
#  10  Similarity_Score       20000 non-null  float64
#  11  Similarity_Level       20000 non-null  str
#  12  First_Response_Date    20000 non-null  str
#  13  Assigned_Agent         20000 non-null  str
#  14  Team                   20000 non-null  str
#  15  SLA_Status             20000 non-null  str
#  16  Reopened               20000 non-null  str
#  17  Resolution_Code        20000 non-null  str
#  18  Department             20000 non-null  str
#  19  Customer_ID            20000 non-null  str
#  20  Channel                20000 non-null  str
#  21  Description            20000 non-null  str
#  22  Tags                   20000 non-null  str
#  23  Product                20000 non-null  str
#  24  Customer_Satisfaction  20000 non-null  int64
#  25  Escalation_Level       20000 non-null  str
#  26  Region                 20000 non-null  str
#  27  Device_Type            20000 non-null  str
#  28  Operating_System       20000 non-null  str
#  29  Resolution_Notes       20000 non-null  str
# dtypes: float64(1), int64(2), str(27)
# memory usage: 4.6 MB

# %%
print(df.dtypes)
# Out:
# Ticket_ID                    str
# Created_Date                 str
# Resolution_Date              str
# Status                       str
# Priority                     str
# Ticket_Type                  str
# Category                     str
# Country                      str
# Cluster_ID                 int64
# Cluster_Name                 str
# Similarity_Score         float64
# Similarity_Level             str
# First_Response_Date          str
# Assigned_Agent               str
# Team                         str
# SLA_Status                   str
# Reopened                     str
# Resolution_Code              str
# Department                   str
# Customer_ID                  str
# Channel                      str
# Description                  str
# Tags                         str
# Product                      str
# Customer_Satisfaction      int64
# Escalation_Level             str
# Region                       str
# Device_Type                  str
# Operating_System             str
# Resolution_Notes             str
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Ticket_ID                0
# Created_Date             0
# Resolution_Date          0
# Status                   0
# Priority                 0
# Ticket_Type              0
# Category                 0
# Country                  0
# Cluster_ID               0
# Cluster_Name             0
# Similarity_Score         0
# Similarity_Level         0
# First_Response_Date      0
# Assigned_Agent           0
# Team                     0
# SLA_Status               0
# Reopened                 0
# Resolution_Code          0
# Department               0
# Customer_ID              0
# Channel                  0
# Description              0
# Tags                     0
# Product                  0
# Customer_Satisfaction    0
# Escalation_Level         0
# Region                   0
# Device_Type              0
# Operating_System         0
# Resolution_Notes         0
# dtype: int64

# %%
print(df["Ticket_Type"].value_counts())
# Out:
# Ticket_Type
# Problem     6730
# Request     6653
# Incident    6617
# Name: count, dtype: int64

# %%
print(df["Priority"].value_counts())
# Out:
# Priority
# Medium      5061
# High        5022
# Low         4963
# Critical    4954
# Name: count, dtype: int64

# %%
print(df["Priority"].value_counts())
# Out:
# Priority
# Medium      5061
# High        5022
# Low         4963
# Critical    4954
# Name: count, dtype: int64

# %%
print(df["Category"].value_counts())
# Out:
# Category
# Database             2624
# Security             2565
# Software             2516
# Hardware             2512
# Access Management    2500
# Network              2438
# Integration          2437
# Email                2408
# Name: count, dtype: int64

# %%
###module 2

# %%
text_columns = df.select_dtypes(include="object").columns

for col in text_columns:
    df[col] = df[col].fillna("Unknown")
# Out:
# C:\Users\devin\AppData\Local\Temp\ipykernel_22392\3233367839.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   text_columns = df.select_dtypes(include="object").columns

# %%
df["Created_Date"] = pd.to_datetime(df["Created_Date"])
df["Resolution_Date"] = pd.to_datetime(df["Resolution_Date"])

# %%
df["Resolution_Duration"] = (
    df["Resolution_Date"] - df["Created_Date"]
).dt.days

# %%
priority_map = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

df["Priority_Score"] = df["Priority"].map(priority_map)
