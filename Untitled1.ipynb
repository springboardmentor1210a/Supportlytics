# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Chrome\customer support ticket.csv")

# %%
df.columns
# Out:
# Index(['ticket_id', 'customer_name', 'customer_email', 'product', 'category',
#        'issue_description', 'resolution_notes', 'priority', 'status',
#        'channel', 'region', 'customer_age', 'customer_gender',
#        'subscription_type', 'customer_tenure_months', 'previous_tickets',
#        'customer_satisfaction_score', 'first_response_time_hours',
#        'resolution_time_hours', 'ticket_created_date', 'ticket_resolved_date',
#        'escalated', 'sla_breached', 'operating_system', 'browser',
#        'payment_method', 'language', 'preferred_contact_time',
#        'issue_complexity_score', 'customer_segment'],
#       dtype='str')

# %%
df["ticket_id"].value_counts()
# Out:
# ticket_id
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
#          ..
# 199996    1
# 199997    1
# 199998    1
# 199999    1
# 200000    1
# Name: count, Length: 200000, dtype: int64

# %%
df["priority"].value_counts()
# Out:
# priority
# High      50241
# Urgent    50143
# Medium    49854
# Low       49762
# Name: count, dtype: int64

# %%
df["category"].value_counts()
# Out:
# category
# Feature Request              20169
# Subscription Cancellation    20096
# Performance Issue            20074
# Security Concern             20040
# Login Issue                  20002
# Payment Problem              19997
# Bug Report                   19981
# Refund Request               19900
# Data Sync Issue              19877
# Account Suspension           19864
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# ticket_id                          0
# customer_name                      0
# customer_email                     0
# product                            0
# category                           0
# issue_description                  0
# resolution_notes                   0
# priority                           0
# status                             0
# channel                            0
# region                             0
# customer_age                       0
# customer_gender                    0
# subscription_type                  0
# customer_tenure_months             0
# previous_tickets                   0
# customer_satisfaction_score        0
# first_response_time_hours          0
# resolution_time_hours              0
# ticket_created_date                0
# ticket_resolved_date               0
# escalated                          0
# sla_breached                       0
# operating_system                   0
# browser                        40023
# ...

# %%
df["browser"] = df["browser"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# ticket_id                      0
# customer_name                  0
# customer_email                 0
# product                        0
# category                       0
# issue_description              0
# resolution_notes               0
# priority                       0
# status                         0
# channel                        0
# region                         0
# customer_age                   0
# customer_gender                0
# subscription_type              0
# customer_tenure_months         0
# previous_tickets               0
# customer_satisfaction_score    0
# first_response_time_hours      0
# resolution_time_hours          0
# ticket_created_date            0
# ticket_resolved_date           0
# escalated                      0
# sla_breached                   0
# operating_system               0
# browser                        0
# payment_method                 0
# language                       0
# preferred_contact_time         0
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Chrome\customer support ticket.csv")

# %%
df["Resolution_Duration"] = df["resolution_time_hours"]

# %%
df[["resolution_time_hours", "Resolution_Duration"]].head()
# Out:
#    resolution_time_hours  Resolution_Duration
# 0                 108.36               108.36
# 1                  87.43                87.43
# 2                  78.50                78.50
# 3                 239.36               239.36
# 4                 122.34               122.34

# %%
priority_map = {
    "Low": 1,
    "Medium": 2,
    "High": 3,
    "Critical": 4
}

df["Priority_Score"] = df["priority"].map(priority_map)

# %%
df[["priority", "Priority_Score"]].head()
# Out:
#   priority  Priority_Score
# 0   Urgent             NaN
# 1   Urgent             NaN
# 2   Medium             2.0
# 3   Medium             2.0
# 4     High             3.0

# %%
df.to_csv("cleaned_customer_support_ticket.csv", index=False)

# %%
import os

os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.android',
#  '.cache',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.ms-ad',
#  '.vscode',
#  '.vscode-shared',
#  'AppData',
#  'Application Data',
#  'cleaned_customer_support_ticket.csv',
#  'Contacts',
#  'Cookies',
#  'CrossDevice',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Links',
#  'Local Settings',
#  'mrsstuexam.com_success.aspx.pdf',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{180cb6e6-8059-11ef-ae06-bebb1419005a}.TM.blf',
#  'NTUSER.DAT{180cb6e6-8059-11ef-ae06-bebb1419005a}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{180cb6e6-8059-11ef-ae06-bebb1419005a}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Videos']

# %%
data_dictionary = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes.astype(str)
})

data_dictionary
# Out:
#                                              Column Name Data Type
# ticket_id                                      ticket_id     int64
# customer_name                              customer_name       str
# customer_email                            customer_email       str
# product                                          product       str
# category                                        category       str
# issue_description                      issue_description       str
# resolution_notes                        resolution_notes       str
# priority                                        priority       str
# status                                            status       str
# channel                                          channel       str
# region                                            region       str
# customer_age                                customer_age     int64
# customer_gender                          customer_gender       str
# ...
