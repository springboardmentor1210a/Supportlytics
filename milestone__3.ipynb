# %%
import pandas as pd
import numpy as np
import random

# %%
# Upload your CSV
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3b4ad3ea-09d1-4059-be58-41aeea48f647" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b4ad3ea-09d1-4059-be58-41aeea48f647">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Read the dataset
df = pd.read_csv(next(iter(uploaded)))

# %%
print("Unique Regions:")
print(df["region"].unique())
# Out:
# Unique Regions:
# ['North America' 'South America' 'Europe' 'Asia' 'Africa' 'Australia'
#  'Unknown']

# %%
df["region"].value_counts()
# Out:
# region
# North America    1947
# Africa           1924
# South America    1917
# Asia             1891
# Australia        1880
# Europe           1849
# Unknown             1
# Name: count, dtype: int64

# %%
country_mapping = {
    "North America": ["USA", "Canada", "Mexico"],
    "South America": ["Brazil", "Argentina", "Chile"],
    "Europe": ["Germany", "France", "United Kingdom"],
    "Asia": ["India", "Japan", "Singapore"],
    "Africa": ["South Africa", "Kenya", "Nigeria"],
    "Australia": ["Australia", "New Zealand"],
    "Unknown": ["Unknown"]
}

# %%
import random

random.seed(42)

df["Country"] = df["region"].apply(
    lambda x: random.choice(country_mapping[x])
)

# %%
print(df["region"].unique())
# Out:
# ['North America' 'South America' 'Europe' 'Asia' 'Africa' 'Australia'
#  'Unknown']

# %%
df[["region", "Country"]].head(15)
# Out:
#            region         Country
# 0   North America          Mexico
# 1   South America          Brazil
# 2          Europe         Germany
# 3            Asia       Singapore
# 4            Asia           Japan
# 5   North America             USA
# 6   North America             USA
# 7   South America          Brazil
# 8          Europe  United Kingdom
# 9          Europe         Germany
# 10         Africa         Nigeria
# 11         Africa         Nigeria
# 12  North America          Mexico
# 13         Africa    South Africa
# 14           Asia       Singapore

# %%
df.to_csv("Processed_IT_Support_Tickets_With_Country.csv", index=False)

print("Country column added successfully!")
# Out:
# Country column added successfully!

# %%
plt.figure(figsize=(10,6))

bars = plt.bar(
    priority_resolution["priority"],
    priority_resolution["resolution_time_hours"],
    edgecolor="black",
    linewidth=1
)

plt.title("Average Resolution Time by Priority",
          fontsize=16,
          fontweight="bold")

plt.xlabel("Priority")
plt.ylabel("Average Resolution Time (Hours)")

plt.grid(axis="y", linestyle="--", alpha=0.4)

# Display values on bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f"{height:.2f}",
        ha="center",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

bars = plt.bar(
    type_resolution["Type"],
    type_resolution["resolution_time_hours"],
    edgecolor="black",
    linewidth=1
)

plt.title(
    "Average Resolution Time by Ticket Type",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Ticket Type")
plt.ylabel("Average Resolution Time (Hours)")

plt.grid(axis="y", linestyle="--", alpha=0.4)

# Display values on bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 1,
        f"{height:.2f}",
        ha="center",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,7))

bars = plt.barh(
    country_resolution["Country"],
    country_resolution["resolution_time_hours"],
    edgecolor="black",
    linewidth=1
)

plt.title(
    "Average Resolution Time by Country",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Average Resolution Time (Hours)")
plt.ylabel("Country")

plt.grid(axis="x", linestyle="--", alpha=0.4)

# Display values
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 0.5,
        bar.get_y() + bar.get_height()/2,
        f"{width:.2f}",
        va="center",
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,7))

bars = plt.barh(
    queue_resolution["Queue"],
    queue_resolution["resolution_time_hours"],
    edgecolor="black",
    linewidth=1
)

plt.title(
    "Average Resolution Time by Support Queue",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Average Resolution Time (Hours)")
plt.ylabel("Support Queue")

plt.grid(axis="x", linestyle="--", alpha=0.4)

# Add values on bars
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 0.5,
        bar.get_y() + bar.get_height()/2,
        f"{width:.2f}",
        va="center",
        fontsize=9
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

bars = plt.bar(
    issue_summary["Type"],
    issue_summary["Ticket Count"],
    edgecolor="black",
    linewidth=1
)

plt.title(
    "High Priority Unresolved Issues by Ticket Type",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Ticket Type")
plt.ylabel("Number of Unresolved Tickets")

plt.grid(axis="y", linestyle="--", alpha=0.4)

# Add values on bars
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        height + 0.5,
        str(int(height)),
        ha="center",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

bars = plt.bar(
    region_counts["Region"],
    region_counts["Ticket Count"],
    edgecolor="black",
    linewidth=1
)

plt.title(
    "Ticket Concentration by Region",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Region")
plt.ylabel("Number of Tickets")

plt.grid(axis="y", linestyle="--", alpha=0.4)

for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x()+bar.get_width()/2,
        height+2,
        str(int(height)),
        ha="center"
    )

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
# !pip install plotly

# %%
import plotly.express as px
import pandas as pd

# %%
fig = px.choropleth(
    country_tickets,
    locations="Country",
    locationmode="country names",
    color="Ticket Count",
    hover_name="Country",
    color_continuous_scale="Plasma",
    title="Ticket Concentration by Country"
)

fig.update_layout(
    title_x=0.5,
    geo=dict(showframe=False, showcoastlines=True)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

heatmap_region = pd.pivot_table(
    df,
    index="region",
    columns="priority",
    values="ticket_id",      # Replace with your ticket ID column
    aggfunc="count",
    fill_value=0
)

plt.figure(figsize=(10,6))

sns.heatmap(
    heatmap_region,
    annot=True,
    cmap="YlOrRd",
    fmt="d",
    linewidths=0.5
)

plt.title("Ticket Concentration by Region")
plt.xlabel("Priority")
plt.ylabel("Region")

plt.show()

# %%
import plotly.express as px

fig = px.scatter_geo(
    dominant_category,
    lat="Latitude",
    lon="Longitude",
    color="category",
    size="Ticket Count",
    hover_name="Country",
    hover_data={
        "category": True,
        "Ticket Count": True,
        "Latitude": False,
        "Longitude": False
    },
    projection="natural earth",
    title="Dominant Issue Category by Country"
)

fig.update_layout(
    title_x=0.5,
    geo=dict(
        showland=True,
        showcountries=True,
        showcoastlines=True,
        landcolor="rgb(240,240,240)"
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.scatter(
    cluster_summary,
    x="Cluster_Size",
    y="Avg_Resolution_Time",
    color="Cluster_Name",
    size="Cluster_Size",
    hover_name="Cluster_Name",
    hover_data={
        "Avg_Similarity": True,
        "Cluster_Size": True,
        "Avg_Resolution_Time": True
    },
    title="Cluster Size vs Average Resolution Time"
)

fig.update_layout(
    title_x=0.5,
    xaxis_title="Cluster Size",
    yaxis_title="Average Resolution Time (Hours)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

bars = plt.barh(
    region_resolution["region"],
    region_resolution["resolution_time_hours"],
    edgecolor="black",
    linewidth=1.2
)

plt.title(
    "Average Resolution Time by Region",
    fontsize=16,
    fontweight="bold"
)

plt.xlabel("Average Resolution Time (Hours)")
plt.ylabel("Region")

plt.grid(axis="x", linestyle="--", alpha=0.4)

# Display values
for bar in bars:
    width = bar.get_width()
    plt.text(
        width + 1,
        bar.get_y() + bar.get_height()/2,
        f"{width:.2f}",
        va="center",
        fontsize=10
    )

plt.tight_layout()
plt.show()

# %%
df.columns.tolist()
# Out:
# ['ticket_id',
#  'customer_name',
#  'customer_email',
#  'product',
#  'category',
#  'issue_description',
#  'resolution_notes',
#  'priority',
#  'status',
#  'channel',
#  'region',
#  'customer_age',
#  'customer_gender',
#  'subscription_type',
#  'customer_tenure_months',
#  'previous_tickets',
#  'customer_satisfaction_score',
#  'first_response_time_hours',
#  'resolution_time_hours',
#  'ticket_created_date',
#  'ticket_resolved_date',
#  'escalated',
#  'sla_breached',
#  'operating_system',
#  'browser',
#  'payment_method',
#  'language',
#  'preferred_contact_time',
#  'issue_complexity_score',
#  'customer_segment',
#  'Resolution_Duration_Days',
#  'Priority_Score',
#  'Type',
#  'Queue',
#  'Similarity_Score',
#  'Cluster_ID',
#  'Cluster_Name']

# %%
df.columns.tolist()
# Out:
# ['ticket_id',
#  'customer_name',
#  'customer_email',
#  'product',
#  'category',
#  'issue_description',
#  'resolution_notes',
#  'priority',
#  'status',
#  'channel',
#  'region',
#  'customer_age',
#  'customer_gender',
#  'subscription_type',
#  'customer_tenure_months',
#  'previous_tickets',
#  'customer_satisfaction_score',
#  'first_response_time_hours',
#  'resolution_time_hours',
#  'ticket_created_date',
#  'ticket_resolved_date',
#  'escalated',
#  'sla_breached',
#  'operating_system',
#  'browser',
#  'payment_method',
#  'language',
#  'preferred_contact_time',
#  'issue_complexity_score',
#  'customer_segment',
#  'Resolution_Duration_Days',
#  'Priority_Score',
#  'Type',
#  'Queue',
#  'Similarity_Score',
#  'Cluster_ID',
#  'Cluster_Name',
#  'Country']

# %%
coordinates = {
    "India": (20.5937, 78.9629),
    "Japan": (36.2048, 138.2529),
    "Singapore": (1.3521, 103.8198),
    "USA": (37.0902, -95.7129),
    "Canada": (56.1304, -106.3468),
    "Mexico": (23.6345, -102.5528),
    "Germany": (51.1657, 10.4515),
    "France": (46.2276, 2.2137),
    "United Kingdom": (55.3781, -3.4360),
    "Brazil": (-14.2350, -51.9253),
    "Argentina": (-38.4161, -63.6167),
    "Chile": (-35.6751, -71.5430),
    "South Africa": (-30.5595, 22.9375),
    "Kenya": (-0.0236, 37.9062),
    "Nigeria": (9.0820, 8.6753),
    "Australia": (-25.2744, 133.7751),
    "New Zealand": (-40.9006, 174.8860),
    "Unknown": (0,0)
}

df["Latitude"] = df["Country"].map(lambda x: coordinates[x][0])
df["Longitude"] = df["Country"].map(lambda x: coordinates[x][1])

# %%
mapping_table = (
    df[["region","Country"]]
    .drop_duplicates()
    .sort_values(["region","Country"])
    .reset_index(drop=True)
)

mapping_table
# Out:
#            region         Country
# 0          Africa           Kenya
# 1          Africa         Nigeria
# 2          Africa    South Africa
# 3            Asia           India
# 4            Asia           Japan
# 5            Asia       Singapore
# 6       Australia       Australia
# 7       Australia     New Zealand
# 8          Europe          France
# 9          Europe         Germany
# 10         Europe  United Kingdom
# 11  North America          Canada
# 12  North America          Mexico
# 13  North America             USA
# 14  South America       Argentina
# 15  South America          Brazil
# 16  South America           Chile
# 17        Unknown         Unknown
