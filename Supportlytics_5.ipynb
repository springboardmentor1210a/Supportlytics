# %% [markdown]
# Supportlytics — IT Support Ticket Analysis
# Week 1: Data Acquisition & Understanding

# %% [markdown]
# 1.1 Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# 1.2 Load the dataset

# %%
df = pd.read_csv('helpdesk_tickets.csv')
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1000000, 11)
#    Ticket_ID Date_Created Date_Resolved  Category  \
# 0          1   2023-11-16    2023-11-23    Access
# 1          2   2023-11-29    2023-12-02  Security
# 2          3   2023-11-29    2023-12-06  Security
# 3          4   2023-11-04    2023-11-09  Software
# 4          5   2023-11-03    2023-11-10    Access
#
#                        Subcategory  Priority       Status  \
# 0  Access denied by auditor policy       Low         Open
# 1         Suspicious DLL injection  Critical         Open
# 2             Suspicious SOC alert       Low      Pending
# 3                     App freezing       Low      On Hold
# 4           Access logging failure  Critical  In Progress
#
#          Assigned_Team  Resolution_Time_Hrs  \
# 0      Desktop Support                 3.56
# 1        Security Team                 4.14
# 2        Security Team                 2.98
# 3  Application Support                 4.45
# 4      Desktop Support                 3.49
#
#                                          Description  Escalated
# 0  User reported Access denied by auditor policy....       True
# 1  User reported Suspicious DLL injection. Furthe...      False
# 2  User reported Suspicious SOC alert. Further in...       True
# 3  User reported App freezing. Further investigat...      False
# 4  User reported Access logging failure. Further ...       True

# %% [markdown]
# 1.3 Inspect structure, column types, and relationships

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 11 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   Ticket_ID            1000000 non-null  int64
#  1   Date_Created         1000000 non-null  str
#  2   Date_Resolved        700057 non-null   str
#  3   Category             1000000 non-null  str
#  4   Subcategory          1000000 non-null  str
#  5   Priority             1000000 non-null  str
#  6   Status               1000000 non-null  str
#  7   Assigned_Team        1000000 non-null  str
#  8   Resolution_Time_Hrs  1000000 non-null  float64
#  9   Description          1000000 non-null  str
#  10  Escalated            1000000 non-null  bool
# dtypes: bool(1), float64(1), int64(1), str(8)
# memory usage: 77.2 MB

# %%
df.describe(include='all').T
# Out:
#                          count unique  \
# Ticket_ID            1000000.0    NaN
# Date_Created           1000000     30
# Date_Resolved           700057     36
# Category               1000000      5
# Subcategory            1000000    493
# Priority               1000000      4
# Status                 1000000      5
# Assigned_Team          1000000      4
# Resolution_Time_Hrs  1000000.0    NaN
# Description            1000000    493
# Escalated              1000000      2
#
#                                                                    top  \
# Ticket_ID                                                          NaN
# Date_Created                                                2023-11-03
# Date_Resolved                                               2023-11-21
# Category                                                      Software
# Subcategory                            Laptop touch screen not working
# Priority                                                           Low
# Status                                                        Resolved
# Assigned_Team                                          Desktop Support
# Resolution_Time_Hrs                                                NaN
# Description          User reported Laptop touch screen not working....
# Escalated                                                        False
#
#                        freq      mean            std  min        25%  \
# Ticket_ID               NaN  500000.5  288675.278932  1.0  250000.75
# Date_Created          33717       NaN            NaN  NaN        NaN
# Date_Resolved         23507       NaN            NaN  NaN        NaN
# Category             200628       NaN            NaN  NaN        NaN
# Subcategory            2166       NaN            NaN  NaN        NaN
# Priority             250419       NaN            NaN  NaN        NaN
# Status               200903       NaN            NaN  NaN        NaN
# Assigned_Team        399425       NaN            NaN  NaN        NaN
# Resolution_Time_Hrs     NaN  5.246152       2.742932  0.5       2.87
# Description            2166       NaN            NaN  NaN        NaN
# Escalated            500089       NaN            NaN  NaN        NaN
#
#                           50%        75%        max
# Ticket_ID            500000.5  750000.25  1000000.0
# Date_Created              NaN        NaN        NaN
# Date_Resolved             NaN        NaN        NaN
# Category                  NaN        NaN        NaN
# Subcategory               NaN        NaN        NaN
# Priority                  NaN        NaN        NaN
# Status                    NaN        NaN        NaN
# Assigned_Team             NaN        NaN        NaN
# Resolution_Time_Hrs      5.24       7.62       10.0
# Description               NaN        NaN        NaN
# Escalated                 NaN        NaN        NaN

# %%
# Unique value counts for categorical columns
cat_cols = ['Category', 'Subcategory', 'Priority', 'Status', 'Assigned_Team', 'Escalated']
for col in cat_cols:
    print(f"--- {col} ({df[col].nunique()} unique) ---")
    print(df[col].value_counts())
    print()
# Out:
# --- Category (5 unique) ---
# Category
# Software    200628
# Security    200004
# Network     199943
# Hardware    199761
# Access      199664
# Name: count, dtype: int64
#
# --- Subcategory (493 unique) ---
# Subcategory
# Laptop touch screen not working           2166
# Laptop motherboard short circuit          2161
# Keyboard malfunction                      2149
# DHCP failure                              2146
# Suspicious cookie theft                   2141
#                                           ...
# Access denied by SOX policy               1900
# Access denied by HIPAA policy             1899
# Access denied by auditor policy           1893
# Access denied by temporary restriction    1892
# Account disabled by policy                1887
# Name: count, Length: 493, dtype: int64
#
# --- Priority (4 unique) ---
# Priority
# Low         250419
# Medium      250158
# High        249853
# Critical    249570
# Name: count, dtype: int64
#
# --- Status (5 unique) ---
# Status
# Resolved       200903
# On Hold        200519
# Open           199802
# In Progress    199435
# Pending        199341
# Name: count, dtype: int64
#
# --- Assigned_Team (4 unique) ---
# Assigned_Team
# Desktop Support        399425
# Application Support    200628
# Security Team          200004
# Network Team           199943
# Name: count, dtype: int64
#
# --- Escalated (2 unique) ---
# Escalated
# False    500089
# True     499911
# Name: count, dtype: int64

# %% [markdown]
# 1.4 Missing values check

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)
pd.DataFrame({'missing_count': missing, 'missing_pct': missing_pct})
# Out:
#                      missing_count  missing_pct
# Ticket_ID                        0         0.00
# Date_Created                     0         0.00
# Date_Resolved               299943        29.99
# Category                         0         0.00
# Subcategory                      0         0.00
# Priority                         0         0.00
# Status                           0         0.00
# Assigned_Team                    0         0.00
# Resolution_Time_Hrs              0         0.00
# Description                      0         0.00
# Escalated                        0         0.00

# %% [markdown]
# 1.5 Duplicate check

# %%
print("Duplicate Ticket_IDs:", df['Ticket_ID'].duplicated().sum())
print("Fully duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate Ticket_IDs: 0
# Fully duplicate rows: 0

# %% [markdown]
# 1.6 Define key metrics

# %%
df['Date_Created'] = pd.to_datetime(df['Date_Created'])
df['Date_Resolved'] = pd.to_datetime(df['Date_Resolved'])

priority_dist = df['Priority'].value_counts(normalize=True).mul(100).round(2)
print("Priority distribution (%):")
print(priority_dist)
# Out:
# Priority distribution (%):
# Priority
# Low         25.04
# Medium      25.02
# High        24.99
# Critical    24.96
# Name: proportion, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
df['Category'].value_counts().plot(kind='bar', ax=axes[0], color='steelblue', title='Ticket Volume by Category')
df['Priority'].value_counts().plot(kind='bar', ax=axes[1], color='indianred', title='Ticket Volume by Priority')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
df['Status'].value_counts().plot(kind='bar', color='steelblue')
plt.title('Ticket Status Distribution')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Week 2 — Data Cleaning and Feature Engineering

# %% [markdown]
# 2.1 Handle missing / incomplete fields

# %%
df['Is_Resolved'] = df['Date_Resolved'].notnull()
print(df['Is_Resolved'].value_counts())

# Cross-check against Status field
pd.crosstab(df['Status'], df['Is_Resolved'])
# Out:
# Is_Resolved
# True     700057
# False    299943
# Name: count, dtype: int64
# Is_Resolved  False   True
# Status
# In Progress  59593  139842
# On Hold      59951  140568
# Open         60044  139758
# Pending      60031  139310
# Resolved     60324  140579

# %% [markdown]
# 2.2 Extract Resolution_Time

# %%
df['Resolution_Time_Days'] = (df['Date_Resolved'] - df['Date_Created']).dt.days
df['Resolution_Time_Computed_Hrs'] = df['Resolution_Time_Days'] * 24

df[['Ticket_ID', 'Date_Created', 'Date_Resolved',
    'Resolution_Time_Hrs', 'Resolution_Time_Computed_Hrs']].head(10)
# Out:
#    Ticket_ID Date_Created Date_Resolved  Resolution_Time_Hrs  \
# 0          1   2023-11-16    2023-11-23                 3.56
# 1          2   2023-11-29    2023-12-02                 4.14
# 2          3   2023-11-29    2023-12-06                 2.98
# 3          4   2023-11-04    2023-11-09                 4.45
# 4          5   2023-11-03    2023-11-10                 3.49
# 5          6   2023-11-04           NaT                 5.29
# 6          7   2023-11-20    2023-11-25                 8.98
# 7          8   2023-11-17    2023-11-20                 7.78
# 8          9   2023-11-28    2023-12-05                 6.57
# 9         10   2023-11-30    2023-12-05                 8.77
#
#    Resolution_Time_Computed_Hrs
# 0                         168.0
# 1                          72.0
# 2                         168.0
# 3                         120.0
# 4                         168.0
# 5                           NaN
# 6                         120.0
# 7                          72.0
# 8                         168.0
# 9                         120.0

# %%
# Sanity check: distribution of the recomputed metric for resolved tickets
resolved = df[df['Is_Resolved']]
resolved['Resolution_Time_Computed_Hrs'].describe()
# Out:
# count    700057.000000
# mean         95.965786
# std          48.003193
# min          24.000000
# 25%          48.000000
# 50%          96.000000
# 75%         144.000000
# max         168.000000
# Name: Resolution_Time_Computed_Hrs, dtype: float64

# %% [markdown]
# 2.3 Categorize performance buckets

# %%
def bucket_resolution(hours):
    if pd.isna(hours):
        return 'Unresolved'
    elif hours <= 48:
        return 'Fast'
    elif hours <= 120:
        return 'Moderate'
    else:
        return 'Slow'

df['Performance_Bucket'] = df['Resolution_Time_Computed_Hrs'].apply(bucket_resolution)
df['Performance_Bucket'].value_counts()
# Out:
# Performance_Bucket
# Moderate      300377
# Unresolved    299943
# Fast          200230
# Slow          199450
# Name: count, dtype: int64

# %% [markdown]
# 2.4 Encode categorical fields

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\MADHU BABU REPALLI\AppData\Roaming\Python\Python314\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# Ordinal encode Priority (has a natural order)
priority_order = {'Low': 0, 'Medium': 1, 'High': 2, 'Critical': 3}
df['Priority_Encoded'] = df['Priority'].map(priority_order)

# One-hot encode nominal fields for downstream modeling/clustering
df_encoded = pd.get_dummies(
    df,
    columns=['Category', 'Status', 'Assigned_Team', 'Performance_Bucket'],
    prefix=['Cat', 'Status', 'Team', 'Perf']
)

# Label encode Subcategory (high cardinality -> keep as single numeric column)
le = LabelEncoder()
df['Subcategory_Encoded'] = le.fit_transform(df['Subcategory'])

df_encoded.head()
# Out:
#    Ticket_ID Date_Created Date_Resolved                      Subcategory  \
# 0          1   2023-11-16    2023-11-23  Access denied by auditor policy
# 1          2   2023-11-29    2023-12-02         Suspicious DLL injection
# 2          3   2023-11-29    2023-12-06             Suspicious SOC alert
# 3          4   2023-11-04    2023-11-09                     App freezing
# 4          5   2023-11-03    2023-11-10           Access logging failure
#
#    Priority  Resolution_Time_Hrs  \
# 0       Low                 3.56
# 1  Critical                 4.14
# 2       Low                 2.98
# 3       Low                 4.45
# 4  Critical                 3.49
#
#                                          Description  Escalated  Is_Resolved  \
# 0  User reported Access denied by auditor policy....       True         True
# 1  User reported Suspicious DLL injection. Furthe...      False         True
# 2  User reported Suspicious SOC alert. Further in...       True         True
# 3  User reported App freezing. Further investigat...      False         True
# 4  User reported Access logging failure. Further ...       True         True
#
#    Resolution_Time_Days  Resolution_Time_Computed_Hrs  Priority_Encoded  \
# 0                   7.0                         168.0                 0
# 1                   3.0                          72.0                 3
# 2                   7.0                         168.0                 0
# 3                   5.0                         120.0                 0
# 4                   7.0                         168.0                 3
#
#    Cat_Access  Cat_Hardware  Cat_Network  Cat_Security  Cat_Software  \
# 0        True         False        False         False         False
# 1       False         False        False          True         False
# 2       False         False        False          True         False
# 3       False         False        False         False          True
# 4        True         False        False         False         False
#
#    Status_In Progress  Status_On Hold  Status_Open  Status_Pending  \
# 0               False           False         True           False
# 1               False           False         True           False
# 2               False           False        False            True
# 3               False            True        False           False
# 4                True           False        False           False
#
#    Status_Resolved  Team_Application Support  Team_Desktop Support  \
# 0            False                     False                  True
# 1            False                     False                 False
# 2            False                     False                 False
# 3            False                      True                 False
# 4            False                     False                  True
#
#    Team_Network Team  Team_Security Team  Perf_Fast  Perf_Moderate  Perf_Slow  \
# 0              False               False      False          False       True
# 1              False                True      False           True      False
# 2              False                True      False          False       True
# 3              False               False      False           True      False
# 4              False               False      False          False       True
#
#    Perf_Unresolved
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
from sklearn.preprocessing import LabelEncoder

# Ordinal encode Priority (has a natural order)
priority_order = {'Low': 0, 'Medium': 1, 'High': 2, 'Critical': 3}
df['Priority_Encoded'] = df['Priority'].map(priority_order)

# One-hot encode nominal fields for downstream modeling/clustering
df_encoded = pd.get_dummies(
    df,
    columns=['Category', 'Status', 'Assigned_Team', 'Performance_Bucket'],
    prefix=['Cat', 'Status', 'Team', 'Perf']
)

# Label encode Subcategory (high cardinality -> keep as single numeric column)
le = LabelEncoder()
df['Subcategory_Encoded'] = le.fit_transform(df['Subcategory'])

df_encoded.head()
# Out:
#    Ticket_ID Date_Created Date_Resolved                      Subcategory  \
# 0          1   2023-11-16    2023-11-23  Access denied by auditor policy
# 1          2   2023-11-29    2023-12-02         Suspicious DLL injection
# 2          3   2023-11-29    2023-12-06             Suspicious SOC alert
# 3          4   2023-11-04    2023-11-09                     App freezing
# 4          5   2023-11-03    2023-11-10           Access logging failure
#
#    Priority  Resolution_Time_Hrs  \
# 0       Low                 3.56
# 1  Critical                 4.14
# 2       Low                 2.98
# 3       Low                 4.45
# 4  Critical                 3.49
#
#                                          Description  Escalated  Is_Resolved  \
# 0  User reported Access denied by auditor policy....       True         True
# 1  User reported Suspicious DLL injection. Furthe...      False         True
# 2  User reported Suspicious SOC alert. Further in...       True         True
# 3  User reported App freezing. Further investigat...      False         True
# 4  User reported Access logging failure. Further ...       True         True
#
#    Resolution_Time_Days  Resolution_Time_Computed_Hrs  Priority_Encoded  \
# 0                   7.0                         168.0                 0
# 1                   3.0                          72.0                 3
# 2                   7.0                         168.0                 0
# 3                   5.0                         120.0                 0
# 4                   7.0                         168.0                 3
#
#    Subcategory_Encoded  Cat_Access  Cat_Hardware  Cat_Network  Cat_Security  \
# 0                   29        True         False        False         False
# 1                  396       False         False        False          True
# 2                  415       False         False        False          True
# 3                   76       False         False        False         False
# 4                   61        True         False        False         False
#
#    Cat_Software  Status_In Progress  Status_On Hold  Status_Open  \
# 0         False               False           False         True
# 1         False               False           False         True
# 2         False               False           False        False
# 3          True               False            True        False
# 4         False                True           False        False
#
#    Status_Pending  Status_Resolved  Team_Application Support  \
# 0           False            False                     False
# 1           False            False                     False
# 2            True            False                     False
# 3           False            False                      True
# 4           False            False                     False
#
#    Team_Desktop Support  Team_Network Team  Team_Security Team  Perf_Fast  \
# 0                  True              False               False      False
# 1                 False              False                True      False
# 2                 False              False                True      False
# 3                 False              False               False      False
# 4                  True              False               False      False
#
#    Perf_Moderate  Perf_Slow  Perf_Unresolved
# 0          False       True            False
# 1           True      False            False
# 2          False       True            False
# 3           True      False            False
# 4          False       True            False

# %% [markdown]
# 2.5 Save the cleaned dataset

# %%
df.to_csv('helpdesk_tickets_cleaned.csv', index=False)
df_encoded.to_csv('helpdesk_tickets_encoded.csv', index=False)
print("Saved cleaned and encoded datasets.")
print("df shape:", df.shape, "| df_encoded shape:", df_encoded.shape)
# Out:
# Saved cleaned and encoded datasets.
# df shape: (1000000, 17) | df_encoded shape: (1000000, 31)

# %% [markdown]
# Module 4: Cluster & Similarity Analysis
#
#  4.0 Building Cluster_ID and Similarity_Score (prerequisite)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity

# Cluster on the 493 unique subcategories only
unique_subcats = df['Subcategory'].drop_duplicates().reset_index(drop=True)
print(f"Unique subcategories to cluster: {len(unique_subcats)}")

tfidf = TfidfVectorizer(stop_words='english', max_features=300)
tfidf_matrix = tfidf.fit_transform(unique_subcats)

N_CLUSTERS = 15
kmeans = KMeans(n_clusters=N_CLUSTERS, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(tfidf_matrix)

# Similarity of each subcategory to its own cluster centroid
centroids = kmeans.cluster_centers_
similarity_scores = [
    cosine_similarity(tfidf_matrix[i], centroids[cluster_labels[i]].reshape(1, -1))[0][0]
    for i in range(len(unique_subcats))
]

cluster_map = pd.DataFrame({
    'Subcategory': unique_subcats,
    'Cluster_ID': cluster_labels,
    'Similarity_Score': similarity_scores
})
cluster_map.head(10)
# Out:
# Unique subcategories to cluster: 493
#                        Subcategory  Cluster_ID  Similarity_Score
# 0  Access denied by auditor policy          10          0.973886
# 1         Suspicious DLL injection           0          0.464938
# 2             Suspicious SOC alert           0          0.455810
# 3                     App freezing           1          0.084434
# 4           Access logging failure           9          0.481351
# 5      Suspicious outbound traffic           0          0.508304
# 6      Unauthorized access attempt           1          0.307032
# 7        Peripheral device failure           9          0.440685
# 8                Access point down           1          0.137426
# 9        Suspicious session hijack           0          0.348114

# %%
# Human-readable cluster names from top TF-IDF terms per cluster
feature_names = tfidf.get_feature_names_out()
cluster_names = {}
for c in range(N_CLUSTERS):
    center = centroids[c]
    top_terms = [feature_names[i] for i in center.argsort()[-3:][::-1]]
    cluster_names[c] = " / ".join(top_terms).title()

cluster_map['Cluster_Name'] = cluster_map['Cluster_ID'].map(cluster_names)

# Similarity_Level bucket (quantile-based)
cluster_map['Similarity_Level'] = pd.qcut(
    cluster_map['Similarity_Score'], q=3, labels=['Low', 'Medium', 'High']
)

# Broadcast back onto the full 1M-row dataset
df = df.merge(cluster_map, on='Subcategory', how='left')
print(df[['Subcategory', 'Cluster_ID', 'Cluster_Name', 'Similarity_Score', 'Similarity_Level']].drop_duplicates().head(10))
print()
print("Rows after merge:", df.shape)
# Out:
#                        Subcategory  Cluster_ID  \
# 0  Access denied by auditor policy          10
# 1         Suspicious DLL injection           0
# 2             Suspicious SOC alert           0
# 3                     App freezing           1
# 4           Access logging failure           9
# 5      Suspicious outbound traffic           0
# 6      Unauthorized access attempt           1
# 7        Peripheral device failure           9
# 8                Access point down           1
# 9        Suspicious session hijack           0
#
#                      Cluster_Name  Similarity_Score Similarity_Level
# 0        Denied / Access / Policy          0.973886             High
# 1  Suspicious / Violation / Alert          0.464938           Medium
# 2  Suspicious / Violation / Alert          0.455810           Medium
# 3      Expired / Access / Attempt          0.084434              Low
# 4       Failure / Network / Login          0.481351           Medium
# 5  Suspicious / Violation / Alert          0.508304           Medium
# 6      Expired / Access / Attempt          0.307032              Low
# 7       Failure / Network / Login          0.440685           Medium
# 8      Expired / Access / Attempt          0.137426              Low
# 9  Suspicious / Violation / Alert          0.348114              Low
#
# Rows after merge: (1000000, 21)

# %% [markdown]
# ### 4.1 Average similarity scores within clusters

# %%
cluster_summary = df.groupby(['Cluster_ID', 'Cluster_Name']).agg(
    Ticket_Count=('Ticket_ID', 'count'),
    Avg_Similarity=('Similarity_Score', 'mean'),
    Avg_Resolution_Hrs=('Resolution_Time_Computed_Hrs', 'mean')
).reset_index().sort_values('Ticket_Count', ascending=False)

cluster_summary
# Out:
#     Cluster_ID                      Cluster_Name  Ticket_Count  \
# 1            1        Expired / Access / Attempt        290149
# 10          10          Denied / Access / Policy        107764
# 0            0    Suspicious / Violation / Alert        107358
# 3            3          Crash / Application / Vm         95274
# 13          13  Network / Misconfigured / Server         83438
# 2            2            Screen / Laptop / Tint         76309
# 9            9         Failure / Network / Login         54788
# 4            4          Error / Network / Access         48808
# 14          14   Detected / Suspicious / Network         46521
# 12          12                Issue / Mouse / Wi         28577
# 5            5       Laptop / Failure / Keyboard         18590
# 11          11    Activity / Suspicious / Kernel         16091
# 7            7      Firewall / Overload / Access         12071
# 6            6      Attack / Suspicious / Middle          8078
# 8            8      Macro / Execution / Detected          6184
#
#     Avg_Similarity  Avg_Resolution_Hrs
# 1         0.130046           95.959348
# 10        0.682668           96.274735
# 0         0.454043           95.965841
# 3         0.770010           95.602122
# 13        0.481368           96.144576
# 2         0.654926           95.901323
# 9         0.546204           95.968113
# 4         0.632009           95.859209
# 14        0.615587           95.898221
# 12        0.584079           95.721920
# 5         0.543926           95.810848
# 11        0.767862           95.916926
# 7         0.654148           96.461809
# 6         0.807129           96.240172
# 8         0.839748           96.581486

# %%
# Viz 1: Average similarity score per cluster
plt.figure(figsize=(10, 6))
sns.barplot(data=cluster_summary.sort_values('Avg_Similarity', ascending=False),
            x='Avg_Similarity', y='Cluster_Name', hue='Cluster_Name', palette='viridis', legend=False)
plt.title('Average Similarity Score by Cluster')
plt.xlabel('Average Similarity Score')
plt.ylabel('Cluster')
plt.tight_layout()
plt.show()

# %%
# Viz 2: Cluster size (ticket count)
plt.figure(figsize=(10, 6))
sns.barplot(data=cluster_summary.sort_values('Ticket_Count', ascending=False),
            x='Ticket_Count', y='Cluster_Name', hue='Cluster_Name', palette='mako', legend=False)
plt.title('Cluster Size (Number of Tickets)')
plt.xlabel('Number of Tickets')
plt.ylabel('Cluster')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.2 Cluster size vs. issue type (Category)

# %%
# Viz 3: Cluster x Category heatmap
cluster_category = pd.crosstab(df['Cluster_Name'], df['Category'])

plt.figure(figsize=(9, 8))
sns.heatmap(cluster_category, cmap='YlGnBu', annot=False, linewidths=0.3)
plt.title('Cluster vs. Category — Ticket Counts')
plt.xlabel('Category')
plt.ylabel('Cluster')
plt.tight_layout()
plt.show()

# %%
# Viz 4: Stacked bar - category composition within each cluster
cluster_category_pct = cluster_category.div(cluster_category.sum(axis=1), axis=0)
cluster_category_pct.plot(kind='barh', stacked=True, figsize=(10, 8), colormap='tab10')
plt.title('Category Composition Within Each Cluster')
plt.xlabel('Share of Tickets')
plt.ylabel('Cluster')
plt.legend(title='Category', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3 Visualizing performance gaps — boxplots

# %%
# Viz 5: Resolution time distribution by cluster
plt.figure(figsize=(11, 6))
order = cluster_summary.sort_values('Avg_Resolution_Hrs')['Cluster_Name']
sns.boxplot(data=df, x='Cluster_Name', y='Resolution_Time_Computed_Hrs', order=order, hue='Cluster_Name',
            palette='coolwarm', legend=False)
plt.title('Resolution Time Distribution by Cluster')
plt.xlabel('Cluster')
plt.ylabel('Resolution Time (Hours)')
plt.xticks(rotation=75, ha='right')
plt.tight_layout()
plt.show()

# %%
# Viz 6: Similarity score distribution by Category
plt.figure(figsize=(9, 6))
sns.boxplot(data=df, x='Category', y='Similarity_Score', hue='Category', palette='Set2', legend=False)
plt.title('Similarity Score Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Similarity Score')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.4 Visualizing performance gaps — scatter plots

# %%
# Viz 7: Cluster size vs average similarity score
plt.figure(figsize=(8, 6))
sns.scatterplot(data=cluster_summary, x='Ticket_Count', y='Avg_Similarity',
                size='Avg_Resolution_Hrs', hue='Avg_Resolution_Hrs', palette='flare', sizes=(50, 300), legend='brief')
for _, row in cluster_summary.iterrows():
    plt.text(row['Ticket_Count'], row['Avg_Similarity'], row['Cluster_Name'][:14], fontsize=8)
plt.title('Cluster Size vs. Average Similarity (bubble = avg resolution time)')
plt.xlabel('Ticket Count (Cluster Size)')
plt.ylabel('Average Similarity Score')
plt.tight_layout()
plt.show()

# %%
# Viz 8: Cluster size vs average resolution time (identifies problem clusters: large + slow)
plt.figure(figsize=(8, 6))
sns.scatterplot(data=cluster_summary, x='Ticket_Count', y='Avg_Resolution_Hrs',
                hue='Avg_Similarity', palette='viridis', s=120)
for _, row in cluster_summary.iterrows():
    plt.text(row['Ticket_Count'], row['Avg_Resolution_Hrs'], row['Cluster_Name'][:14], fontsize=8)
plt.axhline(cluster_summary['Avg_Resolution_Hrs'].mean(), color='red', linestyle='--', alpha=0.5, label='Overall avg')
plt.title('Cluster Size vs. Average Resolution Time (Problem-Cluster Finder)')
plt.xlabel('Ticket Count (Cluster Size)')
plt.ylabel('Average Resolution Time (Hours)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Module 5: Performance Trend Analysis

# %% [markdown]
# ### 5.1 Average resolution time by Priority and Category (Type)

# %%
priority_order = ['Low', 'Medium', 'High', 'Critical']
res_by_priority = df.groupby('Priority')['Resolution_Time_Computed_Hrs'].mean().reindex(priority_order)
res_by_category = df.groupby('Category')['Resolution_Time_Computed_Hrs'].mean().sort_values()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
sns.barplot(x=res_by_priority.index, y=res_by_priority.values, order=priority_order,
            hue=res_by_priority.index, palette='rocket', legend=False, ax=axes[0])
axes[0].set_title('Avg Resolution Time by Priority')
axes[0].set_ylabel('Hours')

sns.barplot(x=res_by_category.index, y=res_by_category.values, hue=res_by_category.index,
            palette='crest', legend=False, ax=axes[1])
axes[1].set_title('Avg Resolution Time by Category (Type)')
axes[1].set_ylabel('Hours')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Which team handles tickets fastest

# %%
team_speed = df.groupby('Assigned_Team')['Resolution_Time_Computed_Hrs'].agg(
    Avg_Resolution_Hrs='mean', Median_Resolution_Hrs='median', Ticket_Count='count'
).sort_values('Avg_Resolution_Hrs')

print(team_speed)

plt.figure(figsize=(8, 5))
sns.barplot(x=team_speed['Avg_Resolution_Hrs'], y=team_speed.index, hue=team_speed.index,
            palette='crest', legend=False)
plt.title('Average Resolution Time by Team (Fastest to Slowest)')
plt.xlabel('Average Resolution Time (Hours)')
plt.ylabel('Team')
plt.tight_layout()
plt.show()
# Out:
#                      Avg_Resolution_Hrs  Median_Resolution_Hrs  Ticket_Count
# Assigned_Team
# Application Support           95.748511                   96.0        140666
# Network Team                  95.931404                   96.0        139950
# Security Team                 95.939985                   96.0        139966
# Desktop Support               96.105283                   96.0        279475

# %% [markdown]
# ### 5.3 High-priority unresolved issues

# %%
high_priority_open = df[(df['Priority'].isin(['High', 'Critical'])) & (~df['Is_Resolved'])]
print(f"High/Critical priority tickets still unresolved: {len(high_priority_open):,} "
      f"({len(high_priority_open) / len(df) * 100:.1f}% of all tickets)")

open_by_team_priority = pd.crosstab(high_priority_open['Assigned_Team'], high_priority_open['Priority'])
print()
print(open_by_team_priority)

open_by_team_priority.plot(kind='bar', stacked=True, figsize=(8, 5), colormap='autumn')
plt.title('Unresolved High/Critical Tickets by Team')
plt.xlabel('Team')
plt.ylabel('Number of Unresolved Tickets')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
# Out:
# High/Critical priority tickets still unresolved: 149,952 (15.0% of all tickets)
#
# Priority             Critical   High
# Assigned_Team
# Application Support     14939  14991
# Desktop Support         30081  29938
# Network Team            15082  14951
# Security Team           15086  14884
